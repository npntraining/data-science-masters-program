# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ### Dist Plot

# %%
sns.distplot(tips["total_bill"])

# %%
sns.distplot(tips["total_bill"],kde=False)

# %%
sns.distplot(tips["total_bill"],kde=False,bins=10)

# %%
sns.distplot(tips["total_bill"],kde=False,bins=5)

# %% [markdown]
# ### Joint Plot

# %%
# Distribution of Total Bill vs 
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex")

# %% [markdown]
# ### Regression Plot

# %%
sns.lmplot(x="total_bill",y="tip",data=tips_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f5caa9bd32e3> in <module>()
# ----> 1 sns.lmplot(x="total_bill",y="tip",data=tips_data)
#
# NameError: name 'tips_data' is not defined
